# %% [markdown]
# <a href="https://colab.research.google.com/github/SAHIL9581/Agentic_model_main/blob/main/agentic_model_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ✅ Step 1: Install required libraries
# !pip install -q pandas google-generativeai

# ✅ Step 2: Import libraries
import pandas as pd
import google.generativeai as genai
from google.colab import files
from IPython.display import display
import warnings
warnings.filterwarnings("ignore")

# %%
# ✅ Load CSV with error handling
try:
    df = pd.read_csv(filename, on_bad_lines='skip')  # Skips bad rows (Pandas ≥ 1.3.0)
    print(f"\n✅ Successfully loaded '{filename}' after skipping malformed rows. Shape: {df.shape}")
    display(df.head())
except Exception as e:
    print(f"❌ Failed to load CSV: {e}")
# Out:
# ✅ Successfully loaded 'Well data.CSV' after skipping malformed rows. Shape: (15406, 47)
#     WSN    UWI (APINum) Well Number Well Name    Well Label Sym Code  \
# 0  2492  42001004370000         6-B       NaN  4.200100e+13  PLUGGAS
# 1  2493  42001004380000         5-B       NaN  4.200100e+13   TA-OIL
# 2  2706  42001300900000       SWD-1       NaN  4.200130e+13    SWDOP
# 3  2712  42001300950000           1       NaN  4.200130e+13      DRY
# 4  2741  42001301360000           1       NaN  4.200130e+13      DRY
#
#                Operator           Hist Oper          Lease Name Lease Nbr  \
# 0  YOUNG MARSHALL R DRL  ROESER & PENDLETON         L C BILLETT       6-B
# 1    ROESER & PENDLETON  ROESER & PENDLETON         BILLETT L R       5-B
# 2     ENR OPERATING LLC  FAULCONER VERNON E        WATHEN BEN H     SWD-1
# 3          SPENCE RALPH        SPENCE RALPH  EZEM G SCARBOROUGH         1
# 4            FARISH W S          FARISH W S           O L ELLIS         1
#
# ...

# %%
# ✅ Step 5: Set your Gemini API key
# 🔐 Get one from https://makersuite.google.com/app/apikey
genai.configure(api_key="AIzaSyBnzOpxdJwCov7KA2DJIN3ZfilPySMIY60")  # <-- Replace with your real key

# ✅ Load the Gemini 1.5 Flash model instead of gemini-pro
model = genai.GenerativeModel("gemini-1.5-flash-latest")

# %%
# ✅ Step 6: Ask a question to Gemini about your dataset

# Convert part of the dataframe to text to send to the model
max_rows_to_send = 30  # You can increase if your dataset is small
data_sample = df.head(max_rows_to_send).to_string(index=False)

# Take question input
question = input("💬 Enter your question about the dataset: ")

# Prepare the prompt for Gemini
prompt = f"""
You are a helpful data analyst.

Here is a preview of a dataset from an oil company (first {max_rows_to_send} rows):

{data_sample}

Question: {question}

Please give a concise answer based only on this data.
"""

# Ask Gemini
response = model.generate_content(prompt)

# Show the response
print("\n🤖 Gemini's Answer:\n")
print(response.text)
# Out:
# 💬 Enter your question about the dataset: could you summarize the data
#
# 🤖 Gemini's Answer:
#
# This dataset contains information on oil wells, including unique identifiers (WSN, UWI), location data (latitude, longitude, coordinates), well status ("OIL", "D&A", etc.),  production information (cumulative oil, gas, water),  operator details,  lease and field names,  formation data, and various dates (completion, spud, permit, abandonment, report).  The data spans multiple years and includes a variety of well types and activities.  Many values are missing (NaN).
